// %%
%%sh
# Install java kernel
wget -q https://github.com/SpencerPark/IJava/releases/download/v1.3.0/ijava-1.3.0.zip
unzip -q ijava-1.3.0.zip
python install.py

# Install proxy for the java kernel
wget -qO- https://gist.github.com/SpencerPark/e2732061ad19c1afa4a33a58cb8f18a9/archive/b6cff2bf09b6832344e576ea1e4731f0fb3df10c.tar.gz | tar xvz --strip-components=1
python install_ipc_proxy_kernel.py --kernel=java --implementation=ipc_proxy_kernel.py
// Out:
// Installed java kernel into "/usr/local/share/jupyter/kernels/java"
// e2732061ad19c1afa4a33a58cb8f18a9-b6cff2bf09b6832344e576ea1e4731f0fb3df10c/install_ipc_proxy_kernel.py
// e2732061ad19c1afa4a33a58cb8f18a9-b6cff2bf09b6832344e576ea1e4731f0fb3df10c/ipc_proxy_kernel.py
// Moving java kernel from /usr/local/share/jupyter/kernels/java...
// Wrote modified kernel.json for java_tcp in /usr/local/share/jupyter/kernels/java_tcp/kernel.json
// Installing the proxy kernel in place of java in /usr/local/share/jupyter/kernels/java
// Installed proxy kernelspec: {"argv": ["/usr/bin/python3", "/usr/local/share/jupyter/kernels/java/ipc_proxy_kernel.py", "{connection_file}", "--kernel=java_tcp"], "env": {}, "display_name": "Java", "language": "java", "interrupt_mode": "message", "metadata": {}}
// Proxy kernel installed. Go to 'Runtime > Change runtime type' and select 'java'
// ...

// %% [markdown]
// EJERCICIO 1

// %%
String HolaMundo;
System.out.println("Hello World");

 int a = 25;
 int b = 10;
String name;
name = "esteban";
String saludo = "¿como estas?";

System.out.println(a+b);
System.out.println(name);
System.out.println(saludo);

char letra = 'A';
boolean esVerdadero = true;
int numero = 42;

String mensaje = String.format("La letra es: %c. ¿Es verdadero? %b. El número es: %d", letra, esVerdadero, numero);
System.out.println(mensaje);

String lenguaje = "Java";
String tarea = "programar";
String mensaje = String.format("¡profe, casi no entendi los encabezados de los ejercicios, lo hice a lo que pude entender, que pena! Estoy aprendiendo a %s en %s.", tarea, lenguaje);
System.out.println(mensaje);
// Out:
// Hello World
// 35
// esteban
// ¿como estas?
// La letra es: A. ¿Es verdadero? true. El número es: 42
// ¡profe, casi no entendi los encabezados de los ejercicios, lo hice a lo que pude entender, que pena! Estoy aprendiendo a programar en Java.

// %% [markdown]
// EJERCICIO 2

// %%
 int a = 25;
 int b = 10;
  System.out.println("La suma de "+a+" y "+b+" es: "+(a+b));
  System.out.println("La resta de "+a+" y "+b+" es: "+(a-b));
  System.out.println("La multiplicaciòn entre "+a+" y "+b+" es: "+(a*b));
  System.out.println("La diviciòn entre "+a+" y "+b+" es: "+(a/b));
  System.out.println("El porcentaje de "+a+" para "+b+" es: "+(a/b*100));
  System.out.println("El exponente de "+a+" elevado a "+b+" es: "+Math.pow(a,b));
  System.out.println("El logaritmo de "+a+" en base de "+b+" es: "+Math.log(a)/ Math.log(b))
// Out:
// La suma de 25 y 10 es: 35
// La resta de 25 y 10 es: 15
// La multiplicaciòn entre 25 y 10 es: 250
// La diviciòn entre 25 y 10 es: 2
// El porcentaje de 25 para 10 es: 200
// El exponente de 25 elevado a 10 es: 9.5367431640625E13
// El lOgaritmo de 25 en base de 10 es: 1.3979400086720375

// %% [markdown]
// EJERCCIO 3

// %%
int numeral1 = 24;
int numeral2 = 17;

System.out.print(numeral1+"%: ");
  for (int i =0; i<numeral1;i++){
 System.out.print(" #");
}
System.out.println();
System.out.print(numeral2+"%: ");
for (int i =0; i<numeral2;i++){
System.out.print(" #");
}
System.out.println();
// Out:
// 24%:  # # # # # # # # # # # # # # # # # # # # # # # #
// 17%:  # # # # # # # # # # # # # # # # #

// %% [markdown]
// ![image.png](data:image/png;base64,...)

// %% [markdown]
// EJERCICIO 4

// %%
int[] celsius = {30, 451, 517, 263, 144, 123, 521, 323, 131, 590, 156, 327, 99, 597, 559, 560, 305, 423, 368, 478, 42, 340, 179, 298, 171, 109, 557, 301, 468, 123, 328};

        for (int i = 0; i < celsius.length; i++) {

            int farenheit = (celsius[i] * 9/5) + 32;

            System.out.println(celsius[i] + " grados celsius convertidos a " +  farenheit + " grados centigrados.");
        }
// Out:
// 30 grados celsius convertidos a 86 grados centigrados.
// 451 grados celsius convertidos a 843 grados centigrados.
// 517 grados celsius convertidos a 962 grados centigrados.
// 263 grados celsius convertidos a 505 grados centigrados.
// 144 grados celsius convertidos a 291 grados centigrados.
// 123 grados celsius convertidos a 253 grados centigrados.
// 521 grados celsius convertidos a 969 grados centigrados.
// 323 grados celsius convertidos a 613 grados centigrados.
// 131 grados celsius convertidos a 267 grados centigrados.
// 590 grados celsius convertidos a 1094 grados centigrados.
// 156 grados celsius convertidos a 312 grados centigrados.
// 327 grados celsius convertidos a 620 grados centigrados.
// 99 grados celsius convertidos a 210 grados centigrados.
// 597 grados celsius convertidos a 1106 grados centigrados.
// 559 grados celsius convertidos a 1038 grados centigrados.
// 560 grados celsius convertidos a 1040 grados centigrados.
// ...

// %% [markdown]
// ![image.png](data:image/png;base64,...)
//
// ![image.png](data:image/png;base64,...)

// %% [markdown]
// EJERCICIO 5

// %%
String nombres = "Juan Esteban";
 int escaleras = 10;

    System.out.println(String.format("%s ha subido %d escaleras, para ir al salon de programacion 2 ", nombres,escaleras));

  // EJEMPLO DOS

String nombre = "Juan";
int edad = 24;
String mensaje = String.format("Hola, mi nombre es %s y tengo %d años.", nombre, edad);
System.out.println(mensaje);

// EJEMPLO TRES

double pi = 3.14159;
String resultado = String.format("El valor de pi con 2 decimales es: %.2f", pi);
System.out.println(resultado);

// EJEMPLO CUATRO

String producto = "Manzana";
double precio = 2.00;
String factura = String.format("%-10s %8.2f", producto, precio);
System.out.println(factura);

  //EJEMPLO CINCO

  import java.util.Date;
Date fecha = new Date();
String cadena = String.format("Hoy es: %tD", fecha);
System.out.println(cadena); // Imprime la fecha en formato mm/dd/aaaa

// EJEMPLO 6

String ciudad = "Bogota,colombia";
String cadena = String.format("vive en %s.", ciudad);
System.out.println(cadena);

// EJEMPLO 7

Date ahora = new Date();
    String Hora = String.format("La hora es: %tT", ahora);
    System.out.println(Hora);
// Out:
// Juan Esteban ha subido 10 escaleras, para ir al salon de programacion 2
// Hola, mi nombre es Juan y tengo 24 años.
// El valor de pi con 2 decimales es: 3.14
// Manzana        2.00
// Hoy es: 08/25/24
// vive en Bogota,colombia.
// La hora es: 04:12:41
